# %% [markdown]
# 1. Write a python program to display all the header tags from‘en.wikipedia.org/wiki/Main_Page’.

# %%
# !pip install bs4
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
Page=requests.get("https://en.wikipedia.org/wiki/Main_Page")
Page
# Out:
# <Response [200]>

# %%
Soup=BeautifulSoup(Page.content)
Soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
Titles= Soup.find_all(['h1','h2','h3','h4','h5','h6'])
Titles
# Out:
# [<h1 class="firstHeading" id="firstHeading">Main Page</h1>,
#  <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>,
#  <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>,
#  <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>,
#  <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>,
#  <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>,
#  <h2 class="mp-h2" id="mp-other"><span class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span></h2>,
# ...

# %%
Titles.text
# Out:
# 'Main Page'

# %%
titles=[]

for i in Titles:
    titles.append(i.text.replace("\n"," "))
titles
# Out:
# ['Main Page',
#  "From today's featured article",
#  'Did you know\xa0...',
#  'In the news',
#  'On this day',
#  "Today's featured picture",
#  'Other areas of Wikipedia',
#  "Wikipedia's sister projects",
#  'Wikipedia languages',
#  'Navigation menu',
#  'Personal tools ',
#  'Namespaces ',
#  'Variants ',
#  'Views ',
#  'More ',
#  ' Search ',
#  'Navigation ',
#  'Contribute ',
#  'Tools ',
#  'Print/export ',
#  'In other projects ',
#  'Languages ']

# %%
Name=[]
for j in Titles:
    Name.append(j.name.replace("\n"," "))
Name
# Out:
# ['h1',
#  'h2',
#  'h2',
#  'h2',
#  'h2',
#  'h2',
#  'h2',
#  'h2',
#  'h2',
#  'h2',
#  'h3',
#  'h3',
#  'h3',
#  'h3',
#  'h3',
#  'h3',
#  'h3',
#  'h3',
#  'h3',
#  'h3',
#  'h3',
#  'h3']

# %%
import pandas as pd

# %%
Headers=pd.DataFrame({})
Headers['Tag']=Name
Headers['Titles']=titles

Headers
# Out:
#    Tag                         Titles
# 0   h1                      Main Page
# 1   h2  From today's featured article
# 2   h2               Did you know ...
# 3   h2                    In the news
# 4   h2                    On this day
# 5   h2       Today's featured picture
# 6   h2       Other areas of Wikipedia
# 7   h2    Wikipedia's sister projects
# 8   h2            Wikipedia languages
# 9   h2                Navigation menu
# 10  h3                Personal tools
# 11  h3                    Namespaces
# 12  h3                      Variants
# 13  h3                         Views
# 14  h3                          More
# 15  h3                        Search
# 16  h3                    Navigation
# 17  h3                    Contribute
# 18  h3                         Tools
# 19  h3                  Print/export
# 20  h3             In other projects
# 21  h3                     Languages

# %% [markdown]
# 2.Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. Name, IMDB rating, Year of release).

# %%
page=requests.get("https://www.imdb.com/list/ls091520106/?sort=list_order,asc&st_dt=&mode=simple&page=1&ref_=ttls_vw_smp")
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)

# %%
rating=soup.find_all("div",class_="col-imdb-rating")
len(rating)
# Out:
# 100

# %%
Rating=[]
for i in rating:
    Rating.append(i.text.replace("\n","").strip())
len(Rating)
# Out:
# 100

# %%
Title=soup.find_all("div",class_="col-title")
Title
# Out:
# [<div class="col-title">
#  <span class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">1.</span>
#  <span title="Frank Darabont (dir.), Tim Robbins, Morgan Freeman">
#  <a href="/title/tt0111161/">The Shawshank Redemption</a>
#  <span class="lister-item-year text-muted unbold">(1994)</span>
#  </span>
#  </span>
#  </div>,
#  <div class="col-title">
#  <span class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">2.</span>
#  <span title="Francis Ford Coppola (dir.), Marlon Brando, Al Pacino">
#  <a href="/title/tt0068646/">The Godfather</a>
#  <span class="lister-item-year text-muted unbold">(1972)</span>
#  </span>
#  </span>
#  </div>,
#  <div class="col-title">
#  <span class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">3.</span>
#  <span title="Francis Ford Coppola (dir.), Al Pacino, Robert De Niro">
#  <a href="/title/tt0071562/">The Godfather: Part II</a>
# ...

# %%
Year=[]

y1=soup.find_all("span",class_="lister-item-year text-muted unbold")

for i in y1:
    Year.append(i.text)
len(Year)
# Out:
# 100

# %%
title=[]
for i in Title:
    title.append(i.text.replace("\n",""))
title
# Out:
# ['1.The Shawshank Redemption(1994)',
#  '2.The Godfather(1972)',
#  '3.The Godfather: Part II(1974)',
#  '4.The Dark Knight(2008)',
#  '5.12 Angry Men(1957)',
#  "6.Schindler's List(1993)",
#  '7.The Lord of the Rings: The Return of the King(2003)',
#  '8.Pulp Fiction(1994)',
#  '9.Il buono, il brutto, il cattivo(1966)',
#  '10.Fight Club(1999)',
#  '11.Joker(2019)',
#  '12.The Lord of the Rings: The Fellowship of the Ring(2001)',
#  '13.Forrest Gump(1994)',
#  '14.Inception(2010)',
#  '15.Star Wars: Episode V - The Empire Strikes Back(1980)',
#  '16.The Lord of the Rings: The Two Towers(2002)',
#  '17.The Matrix(1999)',
#  "18.One Flew Over the Cuckoo's Nest(1975)",
#  '19.Goodfellas(1990)',
#  '20.Shichinin no samurai(1954)',
#  '21.Se7en(1995)',
#  '22.Cidade de Deus(2002)',
#  '23.La vita è bella(1997)',
#  '24.The Silence of the Lambs(1991)',
#  '25.Star Wars(1977)',
#  "26.It's a Wonderful Life(1946)",
#  '27.Saving Private Ryan(1998)',
# ...

# %%
import pandas as pd

# %%
Top100list=pd.DataFrame({})
Top100list['Title']=title
Top100list['Year']=Year
Top100list['Rating']=Rating

Top100list
# Out:
#                                            Title    Year Rating
# 0               1.The Shawshank Redemption(1994)  (1994)    9.3
# 1                          2.The Godfather(1972)  (1972)    9.2
# 2                 3.The Godfather: Part II(1974)  (1974)      9
# 3                        4.The Dark Knight(2008)  (2008)      9
# 4                           5.12 Angry Men(1957)  (1957)      9
# ..                                           ...     ...    ...
# 95                   96.North by Northwest(1959)  (1959)    8.3
# 96                   97.A Clockwork Orange(1971)  (1971)    8.3
# 97                               98.Snatch(2000)  (2000)    8.3
# 98  99.Le fabuleux destin d'Amélie Poulain(2001)  (2001)    8.3
# 99                             100.The Kid(1921)  (1921)    8.3
#
# [100 rows x 3 columns]

# %% [markdown]
# 3.Write a python program to display IMDB’s Top rated 100 Indian movies’ data (i.e. Name, IMDB rating, Year
# of release).

# %%
page=requests.get("https://www.imdb.com/india/top-rated-indian-movies/")
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)

# %%
title=soup.find_all("td",class_="titleColumn")
title
# Out:
# [<td class="titleColumn">
#        1.
#        <a href="/title/tt0093603/" title="Mani Ratnam (dir.), Kamal Haasan, Saranya Ponvannan">Nayakan</a>
#  <span class="secondaryInfo">(1987)</span>
#  </td>,
#  <td class="titleColumn">
#        2.
#        <a href="/title/tt0367495/" title="Sundar C. (dir.), Kamal Haasan, Madhavan">Anbe Sivam</a>
#  <span class="secondaryInfo">(2003)</span>
#  </td>,
#  <td class="titleColumn">
#        3.
#        <a href="/title/tt8176054/" title="Mari Selvaraj (dir.), Kathir, Anandhi">Pariyerum Perumal</a>
#  <span class="secondaryInfo">(2018)</span>
#  </td>,
#  <td class="titleColumn">
#        4.
#        <a href="/title/tt0079221/" title="Hrishikesh Mukherjee (dir.), Amol Palekar, Bindiya Goswami">Golmaal</a>
#  <span class="secondaryInfo">(1979)</span>
#  </td>,
#  <td class="titleColumn">
#        5.
#        <a href="/title/tt7391996/" title="Venkatesh Maha (dir.), Radha Bessy, Subba Rao Vepada">C/o Kancharapalem</a>
# ...

# %%
year=[]

for i in title:
    for j in i.find_all("span"):
        year.append(j.text.replace("\n"," "))

year
# Out:
# ['(1987)',
#  '(2003)',
#  '(2018)',
#  '(1979)',
#  '(2018)',
#  '(1959)',
#  '(1993)',
#  '(1989)',
#  '(2016)',
#  '(1955)',
#  '(2018)',
#  '(1992)',
#  '(2004)',
#  '(2019)',
#  '(2015)',
#  '(2009)',
#  '(2020)',
#  '(2019)',
#  '(2007)',
#  '(2021)',
#  '(2019)',
#  '(1991)',
#  '(2019)',
#  '(2016)',
#  '(2021)',
#  '(1993)',
#  '(2018)',
#  '(1956)',
#  '(1983)',
#  '(1957)',
#  '(2018)',
#  '(2018)',
#  '(1965)',
#  '(2015)',
#  '(2002)',
#  '(1975)',
#  '(1997)',
#  '(1995)',
#  '(2019)',
#  '(2019)',
#  '(2018)',
#  '(2016)',
#  '(2013)',
#  '(2006)',
#  '(2006)',
#  '(2021)',
#  '(2017)',
#  '(2018)',
#  '(2015)',
#  '(2005)',
#  '(2014)',
#  '(1999)',
#  '(2014)',
#  '(1971)',
#  '(1998)',
#  '(2018)',
#  '(2015)',
#  '(2016)',
#  '(2013)',
#  '(2012)',
#  '(2014)',
#  '(2003)',
#  '(2012)',
#  '(2012)',
#  '(2013)',
#  '(2000)',
#  '(2016)',
#  '(1975)',
#  '(2004)',
#  '(2015)',
#  '(2007)',
#  '(2021)',
#  '(2016)',
#  '(2012)',
#  '(2005)',
#  '(2011)',
# ...

# %%
Title=[]
for i in title:
    Title.append(i.text.replace("\n",""))
len(Title)
# Out:
# 250

# %%
rating=soup.find_all("td",class_="ratingColumn imdbRating")
len(rating)
# Out:
# 250

# %%
Rating=[]
for i in rating:
    Rating.append(i.text.replace("\n",""))


import pandas as pd

# %%
Top100Indian_Movies=pd.DataFrame({})
Top100Indian_Movies['Title']=Title[:100]
Top100Indian_Movies['Year']=year[:100]
Top100Indian_Movies['Rating']=Rating[:100]

Top100Indian_Movies
# Out:
#                                                 Title    Year Rating
# 0                               1.      Nayakan(1987)  (1987)    8.5
# 1                            2.      Anbe Sivam(2003)  (2003)    8.5
# 2                     3.      Pariyerum Perumal(2018)  (2018)    8.5
# 3                               4.      Golmaal(1979)  (1979)    8.5
# 4                     5.      C/o Kancharapalem(2018)  (2018)    8.5
# ..                                                ...     ...    ...
# 95                                96.      Roja(1992)  (1992)    8.1
# 96                     97.      Rang De Basanti(2006)  (2006)    8.1
# 97            98.      Uri: The Surgical Strike(2019)  (2019)    8.1
# 98        99.      Lagaan: Once Upon a Time in Ind...  (2001)    8.1
# 99                    100.      Andaz Apna Apna(1994)  (1994)    8.1
#
# [100 rows x 3 columns]

# %% [markdown]
# 4.Write a python program to scrap book name, author name, genre and book review of any 5 books from
# ‘www.bookpage.com’

# %%
page = requests.get("https://bookpage.com/reviews")
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)

# %%
Name=soup.find_all("h4",class_="italic")
Name
# Out:
# [<h4 class="italic">
#  <a href="/reviews/26590-steve-sheinkin-fallout-childrens"> <span style="font-style:normal;">★ </span>Fallout</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/reviews/26624-kat-chow-seeing-ghosts-nonfiction">Seeing Ghosts</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/reviews/26597-mike-duncan-hero-two-worlds-history">Hero of Two Worlds</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/reviews/26567-alex-michaelides-maidens-audio"> <span style="font-style:normal;">★ </span>The Maidens</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/reviews/26581-peter-heller-guide-fiction">The Guide</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/reviews/26477-honoree-fanonne-jeffers-love-songs-w-e-b-du-bois-fiction"> <span style="font-style:normal;">★ </span>The Love Songs of W.E.B. Du Bois</a>
#  </h4>,
#  <h4 class="italic">
#  <a href="/reviews/26589-torben-kuhlmann-einstein-childrens"> <span style="font-style:normal;">★ </span>Einstein</a>
#  </h4>,
# ...

# %%
Book_name=[]
for i in Name:
    Book_name.append(i.text.replace("\n"," "))
Book_name
# Out:
# ['  ★ Fallout ',
#  ' Seeing Ghosts ',
#  ' Hero of Two Worlds ',
#  '  ★ The Maidens ',
#  ' The Guide ',
#  '  ★ The Love Songs of W.E.B. Du Bois ',
#  '  ★ Einstein ',
#  ' A Duke Worth Fighting For ',
#  " The Scoundrel's Daughter ",
#  ' Light Chaser ']

# %%
author=soup.find_all("p",class_="sans bold")
author
# Out:
# [<p class="sans bold">
#  Steve Sheinkin
#  </p>,
#  <p class="sans bold">
#  Kat Chow
#  </p>,
#  <p class="sans bold">
#  Mike Duncan
#  </p>,
#  <p class="sans bold">
#  Alex Michaelides, Louise Brealey, Kobna Holdbrook-Smith
#  </p>,
#  <p class="sans bold">
#  Peter Heller
#  </p>,
#  <p class="sans bold">
#  Honorée Fanonne Jeffers
#  </p>,
#  <p class="sans bold">
#  Torben Kuhlmann
#  </p>,
#  <p class="sans bold">
#  Christina Britton
#  </p>,
#  <p class="sans bold">
#  Anne Gracie
#  </p>,
#  <p class="sans bold">
#  Peter F. Hamilton, Gareth L. Powell
#  </p>]

# %%
Author=[]
for i in author:
    Author.append(i.text.replace("\n"," "))
Author
# Out:
# [' Steve Sheinkin ',
#  ' Kat Chow ',
#  ' Mike Duncan ',
#  ' Alex Michaelides, Louise Brealey, Kobna Holdbrook-Smith ',
#  ' Peter Heller ',
#  ' Honorée Fanonne Jeffers ',
#  ' Torben Kuhlmann ',
#  ' Christina Britton ',
#  ' Anne Gracie ',
#  ' Peter F. Hamilton, Gareth L. Powell ']

# %%
genre=soup.find_all("p",class_="genre-links hidden-phone")
genre
# Out:
# [<p class="genre-links hidden-phone">
#  <a href="/search?book_genre=children_s">Children's</a>
#   /
#  <a href="/search?book_genre=middle_grade">Middle Grade</a>
#  </p>,
#  <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=nonfiction">Nonfiction</a>
#   /
#  <a href="/search?book_genre=memoir">Memoir</a>
#   /
#  <a href="/search?book_genre=family_relationships">Family &amp; Relationships</a>
#  </p>,
#  <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=nonfiction">Nonfiction</a>
#   /
#  <a href="/search?book_genre=history">History</a>
#   /
#  <a href="/search?book_genre=american_history">American History</a>
#  </p>,
#  <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=audio">Audio</a>
#   /
#  <a href="/search?book_genre=mystery_suspense">Mystery &amp; Suspense</a>
#   /
#  <a href="/search?book_genre=suspense">Suspense</a>
#  </p>,
#  <p class="genre-links hidden-phone">
#  <a href="/search?book_genre=fiction">Fiction</a>
# ...

# %%
Genre=[]
for i in genre:
    Genre.append(i.text.replace("\n"," "))
Genre
# Out:
# [" Children's  /  Middle Grade ",
#  ' Nonfiction  /  Memoir  /  Family & Relationships ',
#  ' Nonfiction  /  History  /  American History ',
#  ' Audio  /  Mystery & Suspense  /  Suspense ',
#  ' Fiction  /  Speculative Fiction  /  Thriller ',
#  ' Fiction  /  Historical Fiction ',
#  " Children's  /  Children's Picture Book ",
#  ' Romance  /  Historical Romance ',
#  ' Romance  /  Historical Romance ',
#  ' Science Fiction & Fantasy  /  Science Fiction ']

# %%
des=soup.find_all("p",class_="excerpt")
des
# Out:
# [<p class="excerpt">
#  </p>,
#  <p class="excerpt">
#  Like the experience of grief itself, Kat Chow’s memoir is meditative, fragmentary, sometimes funny and occasionally hopeful.
#  </p>,
#  <p class="excerpt">
#  Mike Duncan’s insightful, impressive biography of the Marquis de Lafayette can be appreciated by history lovers and general readers alike.
#  </p>,
#  <p class="excerpt">
#  Actors Louise Brealey and Kobna Holdbrook-Smith narrate as an investigator and a killer in <strong>The Maidens</strong>, a thriller with more twists than the Minotaur’s labyrinth.
#  </p>,
#  <p class="excerpt">
#  <strong>The Guide</strong> is a glorious getaway in every sense—a wild wilderness trip as well as a suspenseful journey to solve a chilling mystery.
#  </p>,
#  <p class="excerpt">
#  Honorée Fanonne Jeffers weaves an epic ancestral story, showing that where any one person comes from is much more complicated than genetic makeup.
#  </p>,
#  <p class="excerpt">
# ...

# %%
Des=[]
for i in des:
    Des.append(i.text.replace("\n"," "))
Des
# Out:
# [' ',
#  ' Like the experience of grief itself, Kat Chow’s memoir is meditative, fragmentary, sometimes funny and occasionally hopeful. ',
#  ' Mike Duncan’s insightful, impressive biography of the Marquis de Lafayette can be appreciated by history lovers and general readers alike. ',
#  ' Actors Louise Brealey and Kobna Holdbrook-Smith narrate as an investigator and a killer in The Maidens, a thriller with more twists than the Minotaur’s labyrinth. ',
#  ' The Guide is a glorious getaway in every sense—a wild wilderness trip as well as a suspenseful journey to solve a chilling mystery. ',
#  ' Honorée Fanonne Jeffers weaves an epic ancestral story, showing that where any one person comes from is much more complicated than genetic makeup. ',
#  ' Author-illustrator Torben Kuhlmann explores the concept of time in another wildly imaginative mouse adventure, Einstein: The Fantastic Journey of a Mouse Through Space and Time.',
#  ' ',
#  ' ',
#  ' ']

# %%
BookRev=pd.DataFrame({})
BookRev['Name']=Name
BookRev['Genre']=Genre
BookRev['Author']=Author
BookRev['Reviw']=Des

#BookRev.drop([4,5,6],axis=0,inplace=True)
BookRev
# Out:
#                                                 Name  \
# 0                       [\n, [ , [★ ], Fallout], \n]
# 1                          [\n, [Seeing Ghosts], \n]
# 2                     [\n, [Hero of Two Worlds], \n]
# 3                   [\n, [ , [★ ], The Maidens], \n]
# 4                              [\n, [The Guide], \n]
# 5  [\n, [ , [★ ], The Love Songs of W.E.B. Du Boi...
# 6                      [\n, [ , [★ ], Einstein], \n]
# 7              [\n, [A Duke Worth Fighting For], \n]
# 8               [\n, [The Scoundrel's Daughter], \n]
# 9                           [\n, [Light Chaser], \n]
#
#                                                Genre  \
# 0                       Children's  /  Middle Grade
# 1   Nonfiction  /  Memoir  /  Family & Relationsh...
# 2       Nonfiction  /  History  /  American History
# 3         Audio  /  Mystery & Suspense  /  Suspense
# 4      Fiction  /  Speculative Fiction  /  Thriller
# 5                    Fiction  /  Historical Fiction
# ...

# %% [markdown]
# 8.Write a python program to extract information about the local weather from the National Weather Service
# website of USA, https://www.weather.gov/ for the city, San Francisco. You need to extract data about 7 day
# extended forecast display for the city. The data should include period, short description, temperature and
# description.

# %%
page=requests.get("https://forecast.weather.gov/MapClick.php?lat=37.777120000000025&lon=-122.41963999999996#.YSUocogzY2x")
page
# Out:
# <Response [200]>

# %%
Soup=BeautifulSoup(page.content)
Soup
# Out:
# <!DOCTYPE html>
# <html class="no-js">
# <head>
# <!-- Meta -->
# <meta content="width=device-width" name="viewport"/>
# <link href="http://purl.org/dc/elements/1.1/" rel="schema.DC"/><title>National Weather Service</title><meta content="National Weather Service" name="DC.title"/><meta content="NOAA National Weather Service National Weather Service" name="DC.description"/><meta content="US Department of Commerce, NOAA, National Weather Service" name="DC.creator"/><meta content="" name="DC.date.created" scheme="ISO8601"/><meta content="EN-US" name="DC.language" scheme="DCTERMS.RFC1766"/><meta content="weather, National Weather Service" name="DC.keywords"/><meta content="NOAA's National Weather Service" name="DC.publisher"/><meta content="National Weather Service" name="DC.contributor"/><meta content="http://www.weather.gov/disclaimer.php" name="DC.rights"/><meta content="General" name="rating"/><meta content="index,follow" name="robots"/>
# <!-- Icons -->
# ...

# %%
Ext_Forecast=Soup.find_all("div",class_="tombstone-container")
Ext_Forecast
# Out:
# [<div class="tombstone-container">
#  <p class="period-name">Tonight<br/><br/></p>
#  <p><img alt="Tonight: Increasing clouds, with a low around 54. West southwest wind 10 to 18 mph, with gusts as high as 23 mph. " class="forecast-icon" src="newimages/medium/nbkn.png" title="Tonight: Increasing clouds, with a low around 54. West southwest wind 10 to 18 mph, with gusts as high as 23 mph. "/></p><p class="short-desc">Increasing<br/>Clouds</p><p class="temp temp-low">Low: 54 °F</p></div>,
#  <div class="tombstone-container">
#  <p class="period-name">Wednesday<br/><br/></p>
# ...

# %%
ext=[]

for i in Ext_Forecast:
    ext.append(i.text.replace("\n"," "))
ext
# Out:
# [' Tonight IncreasingCloudsLow: 54 °F',
#  ' Wednesday BecomingSunnyHigh: 66 °F',
#  ' WednesdayNight Mostly Clearand Breezythen PartlyCloudyLow: 55 °F',
#  ' Thursday SunnyHigh: 72 °F',
#  ' ThursdayNight Mostly ClearLow: 57 °F',
#  ' Friday SunnyHigh: 74 °F',
#  ' FridayNight Mostly ClearLow: 57 °F',
#  ' Saturday SunnyHigh: 76 °F',
#  ' SaturdayNight Mostly ClearLow: 58 °F']

# %%
short_des=Soup.find_all("p",class_="short-desc")
short_des
# Out:
# [<p class="short-desc">Increasing<br/>Clouds</p>,
#  <p class="short-desc">Becoming<br/>Sunny</p>,
#  <p class="short-desc">Mostly Clear<br/>and Breezy<br/>then Partly<br/>Cloudy</p>,
#  <p class="short-desc">Sunny</p>,
#  <p class="short-desc">Mostly Clear</p>,
#  <p class="short-desc">Sunny</p>,
#  <p class="short-desc">Mostly Clear</p>,
#  <p class="short-desc">Sunny</p>,
#  <p class="short-desc">Mostly Clear</p>]

# %%
Short_des=[]

for i in short_des:
    Short_des.append(i.text.replace("\n"," "))
Short_des
# Out:
# ['IncreasingClouds',
#  'BecomingSunny',
#  'Mostly Clearand Breezythen PartlyCloudy',
#  'Sunny',
#  'Mostly Clear',
#  'Sunny',
#  'Mostly Clear',
#  'Sunny',
#  'Mostly Clear']

# %%
period=Soup.find_all("p",class_="period-name")
period
# Out:
# [<p class="period-name">Tonight<br/><br/></p>,
#  <p class="period-name">Wednesday<br/><br/></p>,
#  <p class="period-name">Wednesday<br/>Night</p>,
#  <p class="period-name">Thursday<br/><br/></p>,
#  <p class="period-name">Thursday<br/>Night</p>,
#  <p class="period-name">Friday<br/><br/></p>,
#  <p class="period-name">Friday<br/>Night</p>,
#  <p class="period-name">Saturday<br/><br/></p>,
#  <p class="period-name">Saturday<br/>Night</p>]

# %%
Period=[]

for i in period:
    Period.append(i.text.replace("\n"," "))

Period
# Out:
# ['Tonight',
#  'Wednesday',
#  'WednesdayNight',
#  'Thursday',
#  'ThursdayNight',
#  'Friday',
#  'FridayNight',
#  'Saturday',
#  'SaturdayNight']

# %%
temp=Soup.find_all("p",{"class":["temp temp-low","temp temp-high"]})
temp
# Out:
# [<p class="temp temp-low">Low: 54 °F</p>,
#  <p class="temp temp-high">High: 66 °F</p>,
#  <p class="temp temp-low">Low: 55 °F</p>,
#  <p class="temp temp-high">High: 72 °F</p>,
#  <p class="temp temp-low">Low: 57 °F</p>,
#  <p class="temp temp-high">High: 74 °F</p>,
#  <p class="temp temp-low">Low: 57 °F</p>,
#  <p class="temp temp-high">High: 76 °F</p>,
#  <p class="temp temp-low">Low: 58 °F</p>]

# %%
Temp=[]
for i in temp:
    Temp.append(i.text.replace("\n"," "))
Temp
# Out:
# ['Low: 54 °F',
#  'High: 66 °F',
#  'Low: 55 °F',
#  'High: 72 °F',
#  'Low: 57 °F',
#  'High: 74 °F',
#  'Low: 57 °F',
#  'High: 76 °F',
#  'Low: 58 °F']

# %%
images=Soup.find_all("div",class_="col-sm-10 forecast-text")
images
# Out:
# [<div class="col-sm-10 forecast-text">Increasing clouds, with a low around 54. West southwest wind 10 to 18 mph, with gusts as high as 23 mph. </div>,
#  <div class="col-sm-10 forecast-text">Cloudy through mid morning, then gradual clearing, with a high near 66. West southwest wind 9 to 14 mph increasing to 15 to 20 mph in the afternoon. Winds could gust as high as 25 mph. </div>,
#  <div class="col-sm-10 forecast-text">Partly cloudy, with a low around 55. Breezy, with a west wind 17 to 22 mph decreasing to 7 to 12 mph after midnight. Winds could gust as high as 29 mph. </div>,
#  <div class="col-sm-10 forecast-text">Sunny, with a high near 72. Light south wind becoming west 13 to 18 mph in the afternoon. Winds could gust as high as 24 mph. </div>,
#  <div class="col-sm-10 forecast-text">Mostly clear, with a low around 57. Southwest wind 8 to 18 mph, with gusts as high as 24 mph. </div>,
#  <div class="col-sm-10 forecast-text">Sunny, with a high near 74.</div>,
# ...

# %%
Images=[]
for i in images:
    Images.append(i.text.replace("\n"," "))
Images

Description=pd.DataFrame({})
Description['des']=Images

Description.drop([9,10,11,12],axis=0,inplace=True)
Description
# Out:
#                                                   des
# 0   Increasing clouds, with a low around 54. West ...
# 1   Cloudy through mid morning, then gradual clear...
# 2   Partly cloudy, with a low around 55. Breezy, w...
# 3   Sunny, with a high near 72. Light south wind b...
# 4   Mostly clear, with a low around 57. Southwest ...
# 5                         Sunny, with a high near 74.
# 6                 Mostly clear, with a low around 57.
# 7                         Sunny, with a high near 76.
# 8                 Mostly clear, with a low around 58.
# 13                        Sunny, with a high near 69.

# %%
import pandas as pd

# %%
Forecast=pd.DataFrame({})
Forecast['Period']=Period
Forecast['Temp']=Temp
Forecast['Short-des']=Short_des
Forecast['Description']=Description

Forecast
# Out:
#            Period         Temp                                Short-des  \
# 0         Tonight   Low: 54 °F                         IncreasingClouds
# 1       Wednesday  High: 66 °F                            BecomingSunny
# 2  WednesdayNight   Low: 55 °F  Mostly Clearand Breezythen PartlyCloudy
# 3        Thursday  High: 72 °F                                    Sunny
# 4   ThursdayNight   Low: 57 °F                             Mostly Clear
# 5          Friday  High: 74 °F                                    Sunny
# 6     FridayNight   Low: 57 °F                             Mostly Clear
# 7        Saturday  High: 76 °F                                    Sunny
# 8   SaturdayNight   Low: 58 °F                             Mostly Clear
#
#                                          Description
# 0  Increasing clouds, with a low around 54. West ...
# 1  Cloudy through mid morning, then gradual clear...
# 2  Partly cloudy, with a low around 55. Breezy, w...
# ...

# %% [markdown]
# 5. Write a python program to scrape cricket rankings from ‘www.icc-cricket.com’. You have toscrape:

# %% [markdown]
# # i) Top 10 ODI teams in men’s cricket along with the records for matches, points andrating

# %%
page=requests.get("https://www.icc-cricket.com/rankings/mens/team-rankings/odi")
page
# Out:
# <Response [200]>

# %%
soup= BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Ranking for ODI teams International Cricket Council" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Ranking for ODI teams International Cricket Council" property="og:title"/>
# ...

# %%
teams=soup.find_all("div",class_="rankings-block__container full rankings-table")
teams
# Out:
# [<div class="rankings-block__container full rankings-table">
#  <table class="table">
#  <thead>
#  <tr class="table-head">
#  <th class="table-head__cell u-text-right">Pos</th>
#  <th class="table-head__cell rankings-table__team">
#  <span class="u-hide-mobile">Team</span>
#  <span class="u-show-mobile">T</span>
#  </th>
#  <th class="table-head__cell u-center-text">
#  <span class="u-hide-mobile">Matches</span>
#  <span class="u-show-mobile">M</span>
#  </th>
#  <th class="table-head__cell u-center-text">
#  <span class="u-hide-mobile">Points</span>
#  <span class="u-show-mobile">P</span>
#  </th>
#  <th class="table-head__cell u-text-right rating">
#  <span class="u-hide-mobile">Rating</span>
#  <span class="u-show-mobile">R</span>
#  </th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr class="rankings-block__banner">
#  <td class="rankings-block__banner--pos">1</td>
#  <td class="rankings-block__banner--team-name">
#  <span class="flag-30 rankings-block__banner--flag NZ"></span>
# ...

# %%
Teams=[]

for i in teams:
    for j in i.find_all("span",class_="u-hide-phablet"):
        Teams.append(j.text.replace("\n"," "))
Teams
# Out:
# ['New Zealand',
#  'England',
#  'Australia',
#  'India',
#  'South Africa',
#  'Pakistan',
#  'Bangladesh',
#  'West Indies',
#  'Sri Lanka',
#  'Afghanistan',
#  'Netherlands',
#  'Ireland',
#  'Zimbabwe',
#  'Scotland',
#  'Oman',
#  'Nepal',
#  'UAE',
#  'Namibia',
#  'United States',
#  'Papua New Guinea']

# %%
rating=soup.find_all("td",{"class":["rankings-block__banner--rating u-text-right","table-body__cell u-text-right rating"]})
rating
# Out:
# [<td class="rankings-block__banner--rating u-text-right">
#                              121
#                              <span class="circle-branding circle-branding--top"></span>
#  <span class="circle-branding circle-branding--bottom"></span>
#  </td>,
#  <td class="table-body__cell u-text-right rating">119</td>,
#  <td class="table-body__cell u-text-right rating">116</td>,
#  <td class="table-body__cell u-text-right rating">113</td>,
#  <td class="table-body__cell u-text-right rating">103</td>,
#  <td class="table-body__cell u-text-right rating">93</td>,
#  <td class="table-body__cell u-text-right rating">91</td>,
#  <td class="table-body__cell u-text-right rating">84</td>,
#  <td class="table-body__cell u-text-right rating">79</td>,
#  <td class="table-body__cell u-text-right rating">62</td>,
#  <td class="table-body__cell u-text-right rating">48</td>,
#  <td class="table-body__cell u-text-right rating">46</td>,
#  <td class="table-body__cell u-text-right rating">38</td>,
# ...

# %%
Rating=[]
for i in rating:
    Rating.append(i.text.replace("\n","").strip())
Rating
# Out:
# ['121',
#  '119',
#  '116',
#  '113',
#  '103',
#  '93',
#  '91',
#  '84',
#  '79',
#  '62',
#  '48',
#  '46',
#  '38',
#  '37',
#  '34',
#  '24',
#  '21',
#  '16',
#  '12',
#  '0']

# %%
matches=soup.find_all("td",class_="rankings-block__banner--matches")
Matches=[]
for i in matches:
    Matches.append(i.text)
Scores=[]
scores=soup.find_all("td",class_="table-body__cell u-center-text")
for i in scores:
    Scores.append(i.text)
for i in range(0,len(Scores),2):
    Matches.append(Scores[i])
Matches
# Out:
# ['17',
#  '32',
#  '28',
#  '32',
#  '22',
#  '27',
#  '29',
#  '30',
#  '29',
#  '17',
#  '7',
#  '23',
#  '17',
#  '7',
#  '7',
#  '5',
#  '9',
#  '6',
#  '8',
#  '5']

# %%
points=soup.find_all("td",class_="rankings-block__banner--points")
Points=[]
for i in points:
    Points.append(i.text)
pts=soup.find_all("td",class_="table-body__cell u-center-text")
Pts=[]
for i in pts:
    Pts.append(i.text)
for i in range(1,len(Pts),2):
    Points.append(Pts[i])
Points
# Out:
# ['2,054',
#  '3,793',
#  '3,244',
#  '3,624',
#  '2,267',
#  '2,524',
#  '2,639',
#  '2,523',
#  '2,303',
#  '1,054',
#  '336',
#  '1,067',
#  '646',
#  '258',
#  '240',
#  '119',
#  '190',
#  '97',
#  '93',
#  '0']

# %%
import pandas as pd

# %%
Top_10men_ODI=pd.DataFrame({})
Top_10men_ODI["Teams"]=Teams[:10]
Top_10men_ODI['Matches']=Matches[:10]
Top_10men_ODI['Points']=Points[:10]
Top_10men_ODI['Rating']=Rating[:10]

Top_10men_ODI
# Out:
#           Teams Matches Points Rating
# 0   New Zealand      17  2,054    121
# 1       England      32  3,793    119
# 2     Australia      28  3,244    116
# 3         India      32  3,624    113
# 4  South Africa      22  2,267    103
# 5      Pakistan      27  2,524     93
# 6    Bangladesh      29  2,639     91
# 7   West Indies      30  2,523     84
# 8     Sri Lanka      29  2,303     79
# 9   Afghanistan      17  1,054     62

# %% [markdown]
# # ii) Top 10 ODI Batsmen in men along with the records of their team and rating.

# %%
page=requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/odi")
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup

# %%
batsmen_name=soup.find_all("div",class_="rankings-block__banner--name")
Batsmen_name=[]
for i in batsmen_name[:1]:
    Batsmen_name.append(i.text)
names=soup.find_all("td",class_="table-body__cell name")
for i in names[:9]:
    for j in i.find_all("a"):
        Batsmen_name.append(j.text)
Batsmen_name
# Out:
# ['Babar Azam',
#  'Virat Kohli',
#  'Rohit Sharma',
#  'Ross Taylor',
#  'Aaron Finch',
#  'Jonny Bairstow',
#  'David Warner',
#  'Quinton de Kock',
#  'Shai Hope',
#  'Kane Williamson']

# %%
rating=soup.find_all("div",class_="rankings-block__banner--rating")
Rating=[]

# %%
other=soup.find_all("td",class_="table-body__cell u-text-right rating")
for i in rating[:1]:
    Rating.append(i.text)
for i in other[:9]:
    Rating.append(i.text)
Rating
# Out:
# ['873', '844', '813', '801', '779', '775', '762', '758', '758', '754']

# %%
country=soup.find_all("div",class_="rankings-block__banner--nationality")
Country=[]
for i in country[:1]:
    Country.append(i.text.replace("\n"," "))
Country
# Out:
# ['  PAK                             873 ']

# %%
c=soup.find_all("span",class_="table-body__logo-text")
c[:9]
# Out:
# [<span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">WI</span>,
#  <span class="table-body__logo-text">NZ</span>]

# %%
for j in c[:9]:
    Country.append(j.text)
Country
# Out:
# ['  PAK                             873 ',
#  'IND',
#  'IND',
#  'NZ',
#  'AUS',
#  'ENG',
#  'AUS',
#  'SA',
#  'WI',
#  'NZ']

# %%
Batsmen=pd.DataFrame({})
Batsmen['Batsmen_name']=Batsmen_name
Batsmen['Rating']=Rating
Batsmen['Country']=Country

Batsmen
# Out:
#       Batsmen_name Rating                                 Country
# 0       Babar Azam    873    PAK                             873
# 1      Virat Kohli    844                                     IND
# 2     Rohit Sharma    813                                     IND
# 3      Ross Taylor    801                                      NZ
# 4      Aaron Finch    779                                     AUS
# 5   Jonny Bairstow    775                                     ENG
# 6     David Warner    762                                     AUS
# 7  Quinton de Kock    758                                      SA
# 8        Shai Hope    758                                      WI
# 9  Kane Williamson    754                                      NZ

# %% [markdown]
# # iii) Top 10 ODI bowlers along with the records of their team andrating.

# %%
url="https://www.icc-cricket.com/rankings/mens/player-rankings/odi"

# %%
page=requests.get(url)
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup

# %%
bowler_name=soup.find_all("div",class_="rankings-block__banner--name")
bowler_name[1:2]
# Out:
# [<div class="rankings-block__banner--name">Trent Boult</div>]

# %%
Bowler_name=[]
for i in bowler_name[1:2]:
    Bowler_name.append(i.text)

# %%
name=soup.find_all("td",class_="table-body__cell name")
for i in name[9:18]:
    Bowler_name.append(i.text.replace("\n"," "))
Bowler_name
# Out:
# ['Trent Boult',
#  ' Josh Hazlewood ',
#  ' Mujeeb Ur Rahman ',
#  ' Chris Woakes ',
#  ' Mehedi Hasan ',
#  ' Matt Henry ',
#  ' Jasprit Bumrah ',
#  ' Mitchell Starc ',
#  ' Shakib Al Hasan ',
#  ' Kagiso Rabada ']

# %%
rating=soup.find_all("div",class_="rankings-block__banner--rating")
Rating=[]

for i in rating[1:2]:
    Rating.append(i.text)

# %%
rat=soup.find_all("td",class_="table-body__cell u-text-right rating")
for j in rat[9:18]:
    Rating.append(j.text.replace("\n"," "))
Rating
# Out:
# ['737', '709', '708', '700', '692', '691', '679', '652', '650', '648']

# %%
country=soup.find_all("div",class_="rankings-block__banner--nationality")
Country=[]

for i in country[1:2]:
    Country.append(i.text.replace("\n"," "))
Country
# Out:
# ['  NZ                             737 ']

# %%
c1=soup.find_all("span",class_="table-body__logo-text")
c1[9:18]
# Out:
# [<span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">AFG</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">BAN</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">BAN</span>,
#  <span class="table-body__logo-text">SA</span>]

# %%
for j in c1[9:18]:
    Country.append(j.text)

Country
# Out:
# ['  NZ                             737 ',
#  'AUS',
#  'AFG',
#  'ENG',
#  'BAN',
#  'NZ',
#  'IND',
#  'AUS',
#  'BAN',
#  'SA']

# %%
Bowlers=pd.DataFrame({})
Bowlers['Bowler_name']=Bowler_name
Bowlers['Rating']=Rating
Bowlers['Country']=Country

Bowlers
# Out:
#           Bowler_name Rating                                Country
# 0         Trent Boult    737    NZ                             737
# 1     Josh Hazlewood     709                                    AUS
# 2   Mujeeb Ur Rahman     708                                    AFG
# 3       Chris Woakes     700                                    ENG
# 4       Mehedi Hasan     692                                    BAN
# 5         Matt Henry     691                                     NZ
# 6     Jasprit Bumrah     679                                    IND
# 7     Mitchell Starc     652                                    AUS
# 8    Shakib Al Hasan     650                                    BAN
# 9      Kagiso Rabada     648                                     SA

# %% [markdown]
# 6.Write a python program to scrape cricket rankings from ‘www.icc-cricket.com’. You have toscrape:

# %% [markdown]
# # i) Top 10 ODI teams in women’s cricket along with the records for matches, points andrating.

# %%
page=requests.get("https://www.icc-cricket.com/rankings/womens/team-rankings/odi")
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Ranking for ODI teams International Cricket Council" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Ranking for ODI teams International Cricket Council" property="og:title"/>
# ...

# %%
Team=soup.find_all("span",class_="u-hide-phablet")
Team
# Out:
# [<span class="u-hide-phablet">Australia</span>,
#  <span class="u-hide-phablet">England</span>,
#  <span class="u-hide-phablet">South Africa</span>,
#  <span class="u-hide-phablet">India</span>,
#  <span class="u-hide-phablet">New Zealand</span>,
#  <span class="u-hide-phablet">West Indies</span>,
#  <span class="u-hide-phablet">Pakistan</span>,
#  <span class="u-hide-phablet">Bangladesh</span>,
#  <span class="u-hide-phablet">Sri Lanka</span>,
#  <span class="u-hide-phablet">Ireland</span>,
#  <span class="icn icn-facebook-circle u-hide-phablet"></span>,
#  <span class="icn icn-twitter-circle u-hide-phablet"></span>,
#  <span class="icn icn-instagram-circle u-hide-phablet"></span>,
#  <span class="icn icn-youtube-circle u-hide-phablet"></span>,
#  <span class="icn icn-tiktok-circle u-hide-phablet"></span>]

# %%
WTeam=[]
for i in Team[:10]:
    WTeam.append(i.text)

WTeam
# Out:
# ['Australia',
#  'England',
#  'South Africa',
#  'India',
#  'New Zealand',
#  'West Indies',
#  'Pakistan',
#  'Bangladesh',
#  'Sri Lanka',
#  'Ireland']

# %%
rating=soup.find_all("td",{"class":["rankings-block__banner--rating u-text-right","table-body__cell u-text-right rating"]})
rating
# Out:
# [<td class="rankings-block__banner--rating u-text-right">
#                              164
#                              <span class="circle-branding circle-branding--top"></span>
#  <span class="circle-branding circle-branding--bottom"></span>
#  </td>,
#  <td class="table-body__cell u-text-right rating">119</td>,
#  <td class="table-body__cell u-text-right rating">118</td>,
#  <td class="table-body__cell u-text-right rating">110</td>,
#  <td class="table-body__cell u-text-right rating">93</td>,
#  <td class="table-body__cell u-text-right rating">84</td>,
#  <td class="table-body__cell u-text-right rating">75</td>,
#  <td class="table-body__cell u-text-right rating">61</td>,
#  <td class="table-body__cell u-text-right rating">47</td>,
#  <td class="table-body__cell u-text-right rating">13</td>]

# %%
Rating=[]
for i in rating:
    Rating.append(i.text.replace("\n"," ").strip())

Rating
# Out:
# ['164', '119', '118', '110', '93', '84', '75', '61', '47', '13']

# %%
matches=soup.find_all("td",class_="rankings-block__banner--matches")
matches
# Out:
# [<td class="rankings-block__banner--matches">18</td>]

# %%
Matches=[]
for i in matches:
    Matches.append(i.text)

Matches
# Out:
# ['18']

# %%
m=soup.find_all("td",class_="table-body__cell u-center-text")
M=[]
for i in m:
    M.append(i.text.replace("\n"," "))

for j in range(0,len(M),2):
    Matches.append(M[j])


Matches
# Out:
# ['18', '20', '24', '23', '21', '17', '20', '5', '11', '2']

# %%
wpoints=soup.find_all("td",class_="rankings-block__banner--points")
wpoints
# Out:
# [<td class="rankings-block__banner--points">2,955</td>]

# %%
WPoints=[]
for i in wpoints:
    WPoints.append(i.text)
WPoints
# Out:
# ['2,955']

# %%
wpts=soup.find_all("td",class_="table-body__cell u-center-text")
WPts=[]
for i in wpts:
    WPts.append(i.text)
for i in range(1,len(Pts),2):
    WPoints.append(Pts[i])
WPoints
# Out:
# ['2,955',
#  '2,370',
#  '2,828',
#  '2,535',
#  '1,947',
#  '1,427',
#  '1,496',
#  '306',
#  '519',
#  '25']

# %%
Top_10_WomenTeam=pd.DataFrame({})
Top_10_WomenTeam['Team']=WTeam
Top_10_WomenTeam['Matches']=Matches
Top_10_WomenTeam['Points']=WPoints
Top_10_WomenTeam['Rating']=Rating

Top_10_WomenTeam
# Out:
#            Team Matches Points Rating
# 0     Australia      18  2,955    164
# 1       England      20  2,370    119
# 2  South Africa      24  2,828    118
# 3         India      23  2,535    110
# 4   New Zealand      21  1,947     93
# 5   West Indies      17  1,427     84
# 6      Pakistan      20  1,496     75
# 7    Bangladesh       5    306     61
# 8     Sri Lanka      11    519     47
# 9       Ireland       2     25     13

# %% [markdown]
# # ii) Top 10 women’s ODI players along with the records of their team and rating.

# %%
page = requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi")
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC ODI Match Player Rankings International Cricket Council" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC ODI Match Player Rankings International Cricket Council" property="og:title"/>
# ...

# %%
wBatting=soup.find_all("div",class_="rankings-block__banner--name")
WBatting=[]

# %%
for i in wBatting[:1]:
    WBatting.append(i.text)
WBatting
# Out:
# ['Mithali Raj']

# %%
W=[]
w=soup.find_all("td",class_="table-body__cell name")
for i in w:
    for j in i.find_all("a"):
        WBatting.append(j.text)

WBatting[:9]
# Out:
# ['Mithali Raj',
#  'Lizelle Lee',
#  'Alyssa Healy',
#  'Tammy Beaumont',
#  'Stafanie Taylor',
#  'Meg Lanning',
#  'Amy Satterthwaite',
#  'Natalie Sciver',
#  'Smriti Mandhana']

# %%
wrating=soup.find_all("div",class_="rankings-block__banner--rating")
WRating=[]
for i in rating[:1]:
    WRating.append(i.text)
WRating
# Out:
# ['762']

# %%
r_other=soup.find_all("td",class_="table-body__cell u-text-right rating")
for j in r_other[:9]:
    WRating.append(j.text)
WRating
# Out:
# ['762', '758', '756', '754', '736', '723', '715', '706', '701', '683']

# %%
nation=soup.find_all("div",class_="rankings-block__banner--nationality")
Nation=[]

for i in nation[:1]:
    Nation.append(i.text.replace("\n"," ").strip())

Nation
# Out:
# ['IND                             762']

# %%
o_nation=soup.find_all("span",class_="table-body__logo-text")
for i in o_nation[:9]:
    Nation.append(i.text)

Nation
# Out:
# ['IND                             762',
#  'SA',
#  'AUS',
#  'ENG',
#  'WI',
#  'AUS',
#  'NZ',
#  'ENG',
#  'IND',
#  'SA']

# %%
W_Batting=pd.DataFrame({})
W_Batting['Name']=WBatting[:10]
W_Batting['Rating']=WRating
W_Batting['Team']=Nation

W_Batting
# Out:
#                 Name Rating                                 Team
# 0        Mithali Raj    762  IND                             762
# 1        Lizelle Lee    758                                   SA
# 2       Alyssa Healy    756                                  AUS
# 3     Tammy Beaumont    754                                  ENG
# 4    Stafanie Taylor    736                                   WI
# 5        Meg Lanning    723                                  AUS
# 6  Amy Satterthwaite    715                                   NZ
# 7     Natalie Sciver    706                                  ENG
# 8    Smriti Mandhana    701                                  IND
# 9    Laura Wolvaardt    683                                   SA

# %% [markdown]
# # iii) Top 10 women’s ODI all-rounder along with the records of their team andrating

# %%
Allrounder_name=[]
allrounder_name=soup.find_all("div",class_="rankings-block__banner--name")
for i in allrounder_name[2:3]:
    Allrounder_name.append(i.text)

Allrounder_name
# Out:
# ['Marizanne Kapp']

# %%
N=[]
name1=soup.find_all("td",class_="table-body__cell name")
for i in name1[18:27]:
    for j in i.find_all("a"):
        N.append(j.text)
        
N
# Out:
# ['Ellyse Perry',
#  'Stafanie Taylor',
#  'Natalie Sciver',
#  'Deepti Sharma',
#  'Jess Jonassen',
#  'Ashleigh Gardner',
#  'Dane van Niekerk',
#  'Sophie Devine',
#  'Katherine Brunt']

# %%
for k in N:
    Allrounder_name.append(k)

Allrounder_name
# Out:
# ['Marizanne Kapp',
#  'Ellyse Perry',
#  'Stafanie Taylor',
#  'Natalie Sciver',
#  'Deepti Sharma',
#  'Jess Jonassen',
#  'Ashleigh Gardner',
#  'Dane van Niekerk',
#  'Sophie Devine',
#  'Katherine Brunt']

# %%
allrounder_rating=soup.find_all("div",class_="rankings-block__banner--rating")
Allrounder_rating=[]
for i in allrounder_rating[2:3]:
    Allrounder_rating.append(i.text)

# %%
ar1=soup.find_all("td",class_="table-body__cell u-text-right rating")
for i in ar1[18:27]:
    Allrounder_rating.append(i.text)
Allrounder_rating
# Out:
# ['418', '418', '394', '365', '331', '307', '252', '243', '242', '239']

# %%
cname=soup.find_all("div",class_="rankings-block__banner--nationality")
Cname=[]
for i in cname[2:3]:
    Cname.append(i.text.replace("\n"," "))
    
Cname
# Out:
# ['  SA                             418 ']

# %%
cn=soup.find_all("span",class_="table-body__logo-text")
for i in cn[18:27]:
    Cname.append(i.text)
Cname
# Out:
# ['  SA                             418 ',
#  'AUS',
#  'WI',
#  'ENG',
#  'IND',
#  'AUS',
#  'AUS',
#  'SA',
#  'NZ',
#  'ENG']

# %%
W_AllRounder=pd.DataFrame({})
W_AllRounder['Name']=Allrounder_name
W_AllRounder['Rating']=Allrounder_rating
W_AllRounder['Team']=Cname

W_AllRounder
# Out:
#                Name Rating                                   Team
# 0    Marizanne Kapp    418    SA                             418
# 1      Ellyse Perry    418                                    AUS
# 2   Stafanie Taylor    394                                     WI
# 3    Natalie Sciver    365                                    ENG
# 4     Deepti Sharma    331                                    IND
# 5     Jess Jonassen    307                                    AUS
# 6  Ashleigh Gardner    252                                    AUS
# 7  Dane van Niekerk    243                                     SA
# 8     Sophie Devine    242                                     NZ
# 9   Katherine Brunt    239                                    ENG

# %% [markdown]
# 9. Write a python program to scrape fresher job listings from ‘https://internshala.com/’. It should include job title, company name, CTC, and apply date.¶

# %%
page=requests.get("https://internshala.com/fresher-jobs")
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="https://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta content="IE=9" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0 user-scalable=0" name="viewport"/>
# <meta content="272234782795210" property="fb:app_id"/>
# <meta content="article" property="og:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="630" property="og:image:height"/>
# <meta content="@Internshala" name="twitter:site"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@internshala" name="twitter:creator"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="#ffffff" name="msapplication-navbutton-color"/>
# <meta content="telephone=no" name="format-detection"/>
# <link as="font" crossorigin="" href="/static/fonts/Inter.woff2?v=3.11" rel="preload" type="font/woff2"/>
# ...

# %%
Title=soup.find_all("div",class_="heading_4_5 profile")

Titles=[]
for i in Title:
    for j in i.find_all("a"):
        Titles.append(j.text)
             

Titles
# Out:
# ['OMNI SPORT LEADER',
#  'Executive/Senior Executive - Partnerships',
#  'Executive - Sales',
#  'Junior Operations Executive',
#  'Digital Marketing Executive',
#  'Corporate Sales Manager',
#  'Software Developer',
#  'Executive Assistant To Director',
#  'C++ Embedded/Semiconductor Expert (SoC Modeling)',
#  'Mobile App Developer',
#  'Software Developer',
#  'Coding Teacher (Remote)',
#  'Validation Expert',
#  'Full Stack Developer',
#  'Business Development Associate',
#  'Content & E-commerce Management Executive',
#  'Business Development Specialist',
#  'Assistant Manager - Outreach & Events',
#  'Investor Pitch Deck - Content Writer',
#  'Full Stack Engineer (MERN)',
#  'Business Development Executive',
#  'Junior Graphic Designer',
#  'Sales Development Representative',
#  'Junior Sales Executive',
#  'Online Coding Educator',
#  'Executive - Statistical Modeling',
#  'Customer Experience And Sales Advisor',
#  'Firmware Engineer',
#  'Junior Software Developer',
# ...

# %%
len(Titles)
# Out:
# 40

# %%
Company_name=[]
company_name=soup.find_all("div",class_="heading_6 company_name")
for i in company_name:
    Company_name.append(i.text.replace("\n"," ").strip())

Company_name
# Out:
# ['Decathlon Sport India Private Limited',
#  'Freecharge Payments Technology Private Limited',
#  'Freecharge Payments Technology Private Limited',
#  'Freecharge Payments Technology Private Limited',
#  'TradeVinder',
#  'FinDestination',
#  'Innovantes IT Solutions LLP',
#  'Best Roadways Limited',
#  'Circuitsutra Technologies Private Limited',
#  'Cogent Web Services',
#  'Swabhav Techlabs',
#  'Codingal Education Private Limited',
#  'Apna',
#  'ImbueDesk',
#  'Tutedude',
#  'Anmol Baby',
#  'The SmartWare',
#  'Formskart',
#  'PitchyDeck',
#  'Softway Solutions Private Limited',
#  'Volopay',
#  'Habitate Technologies Private Limited',
#  'Ziguar',
#  'Picocrew',
#  'BrightChamps Tech Private Limited',
#  "D'Well Research",
#  'Tilfi Banaras',
#  'NBase2 Systems Private Limited',
#  'Finnovus Technologies Private Limited (CreditSiddhi)',
#  'Getart',
#  'Krenai',
#  'MiM-Essay',
#  'Finvision Financial Services',
#  'Etchcraft',
#  'Dolphin Engineers',
#  'Flurn Technologies',
# ...

# %%
len(Company_name)
# Out:
# 40

# %%
Date=soup.find_all("div",class_="item_body")
date=[]
for i in Date:
    date.append(i.text)

Apply_date=[]

for i in range(2,len(date),3):
    Apply_date.append(date[i])

Apply_date
# Out:
# ["18 Sep' 21",
#  "11 Sep' 21",
#  "11 Sep' 21",
#  "4 Sep' 21",
#  "24 Sep' 21",
#  "24 Sep' 21",
#  "24 Sep' 21",
#  "24 Sep' 21",
#  "24 Sep' 21",
#  "23 Sep' 21",
#  "23 Sep' 21",
#  "23 Sep' 21",
#  "23 Sep' 21",
#  "23 Sep' 21",
#  "23 Sep' 21",
#  "23 Sep' 21",
#  "23 Sep' 21",
#  "23 Sep' 21",
#  "23 Sep' 21",
#  "23 Sep' 21",
#  "23 Sep' 21",
#  "23 Sep' 21",
#  "23 Sep' 21",
#  "23 Sep' 21",
#  "23 Sep' 21",
#  "23 Sep' 21",
#  "23 Sep' 21",
#  "22 Sep' 21",
#  "22 Sep' 21",
#  "22 Sep' 21",
#  "22 Sep' 21",
#  "22 Sep' 21",
#  "22 Sep' 21",
#  "22 Sep' 21",
#  "22 Sep' 21",
#  "22 Sep' 21",
#  "22 Sep' 21",
#  "22 Sep' 21",
#  "22 Sep' 21",
#  "22 Sep' 21"]

# %%
len(Apply_date)
# Out:
# 40

# %%
ctc=soup.find_all("div",class_="item_body")
Ctc=[]

# %%
for i in ctc:
    for j in i.find_all("i"):
        Ctc.append(i.text.replace("\n","").strip())

Ctc
# Out:
# ['3 - 4 LPA',
#  '3 - 4.2 LPA',
#  '3 - 3.5 LPA',
#  '3 - 4 LPA',
#  '3 - 4 LPA',
#  '3 LPA',
#  '3 - 3.1 LPA',
#  '3 LPA',
#  '6 LPA',
#  '3 LPA',
#  '3 - 3.5 LPA',
#  '3 - 6 LPA',
#  '3 LPA',
#  '5 - 9 LPA',
#  '3 - 4 LPA',
#  '3 - 3.1 LPA',
#  '3 LPA',
#  '3 LPA',
#  '3 - 4.5 LPA',
#  '5.5 - 8 LPA',
#  '3.6 - 5 LPA',
#  '3.2 - 3.6 LPA',
#  '4 - 6 LPA',
#  '3 LPA',
#  '3 - 7.5 LPA',
#  '3 - 3.5 LPA',
#  '3 - 4.8 LPA',
#  '3 LPA',
#  '3 - 3.5 LPA',
#  '4 - 6 LPA',
#  '3.4 - 4.5 LPA',
#  '4 - 4.5 LPA',
#  '3 - 3.5 LPA',
#  '3 - 3.6 LPA',
#  '3 LPA',
#  '3 - 6 LPA',
#  '3 LPA',
#  '3 - 5 LPA',
#  '3.25 - 3.75 LPA',
#  '3 - 3.5 LPA']

# %%
FresherJobs=pd.DataFrame({})
FresherJobs['Title']=Titles
FresherJobs['Company name']=Company_name
FresherJobs['Apply_date']=Apply_date
FresherJobs['CTC']=Ctc

FresherJobs[:10]
# Out:
#                                               Title  \
# 0                                 OMNI SPORT LEADER
# 1         Executive/Senior Executive - Partnerships
# 2                                 Executive - Sales
# 3                       Junior Operations Executive
# 4                       Digital Marketing Executive
# 5                           Corporate Sales Manager
# 6                                Software Developer
# 7                   Executive Assistant To Director
# 8  C++ Embedded/Semiconductor Expert (SoC Modeling)
# 9                              Mobile App Developer
#
#                                      Company name  Apply_date          CTC
# 0           Decathlon Sport India Private Limited  18 Sep' 21    3 - 4 LPA
# 1  Freecharge Payments Technology Private Limited  11 Sep' 21  3 - 4.2 LPA
# 2  Freecharge Payments Technology Private Limited  11 Sep' 21  3 - 3.5 LPA
# 3  Freecharge Payments Technology Private Limited   4 Sep' 21    3 - 4 LPA
# ...

# %% [markdown]
# 10.Write a python program to scrape house details from https://www.nobroker.in/ for any location. It should
# include house title, location, area, emi and price

# %%
pg=requests.get("https://www.nobroker.in/property/sale/hyderabad/Gachibowli?searchParam=W3sibGF0IjoxNy40NDAwODAyLCJsb24iOjc4LjM0ODkxNjgsInBsYWNlSWQiOiJDaElKMzg3ZWRxS1R5enNSNGtTVGI1N25FaXciLCJwbGFjZU5hbWUiOiJHYWNoaWJvd2xpIn1d&radius=2.0&type=BHK2&propertyAge=0")
pg
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(pg.content)

# %%
h_title=soup.find_all("h2",class_="heading-6 font-semi-bold nb__1AShY")
H_title=[]
for i in h_title:
    H_title.append(i.text.strip())

H_title
# Out:
# ['2 BHK Flat  For Sale  In L&t Serene County  In Serene County',
#  '2 BHK Flat  For Sale  In Gayathri Imperial, In Gachibowli',
#  '2 BHK Flat  For Sale  In Veenus Excellance Apartment In Gachibowli',
#  '2 BHK Flat  For Sale  In Golf Edge In Gachibowli',
#  '2 BHK Flat  For Sale  In Mokshagna Castle In Mokshagna Castle',
#  '2 BHK Flat  For Sale  In Sai Residency, Gachibowli In Rahmat Gulshan Colony',
#  '2 BHK Flat  For Sale  In G K Arcade In Nanakramguda',
#  '2 BHK Apartment  For Sale  In My Home Vihanga In Gachibowli',
#  '2 BHK Apartment  For Sale  In My Home Krishe In Gachibowli',
#  '2 BHK Apartment  For Sale  In Shriya Sk Wonders Ncb In Gachibowli Kondapur']

# %%
loc=soup.find_all("div",class_="nb__2CMjv")
Loc=[]
for i in loc:
    Loc.append(i.text)

Loc
# Out:
# ['Gachibowli',
#  'Gayathri Imperial, Plot 54 A Indira Nagar, Gachibowli',
#  'Near qcity, Gowlidoddy journalist colony',
#  'Financial District, Gachibowli, Hyderabad, Telangana 500032, India',
#  'Gachibowli ',
#  'p janardhan reddy nagar gachibowli',
#  'GOuli doddi,near Q City',
#  'My Home Vihanga\xa0 Near Wipro Junction, Gachibowli, Hyderabad, Telangana, INDIA.',
#  'My Home Krishe\xa0 Financial District, Gachibowli, Hyderabad, Telangana, INDIA.',
#  'Shriya Sk Wonders Ncb\xa0 Masjid Banda Main Rd Besides SBI Bank, NCB Enclave, Gachibowli Kondapur']

# %%
area=soup.find_all("div",class_="nb__3oNyC")
Area=[]
for i in area:
    Area.append(i.text)
    
Area
# Out:
# ['1,178 sqft',
#  '1,050 sqft',
#  '1,000 sqft',
#  '1,104 sqft',
#  '1,264 sqft',
#  '1,200 sqft',
#  '1,210 sqft',
#  '1,275 sqft',
#  '1,275 sqft',
#  '1,350 sqft']

# %%
emi=soup.find_all("div",class_="font-semi-bold heading-6")
Emi=[]
for i in emi:
    Emi.append(i.text)

Emi

Est_Emi=[]

for i in range(1, len(Emi), 3):
    Est_Emi.append(Emi[i])
Est_Emi
# Out:
# ['₹57,314/Month',
#  '₹37,254/Month',
#  '₹34,388/Month',
#  '₹57,314/Month',
#  '₹50,436/Month',
#  '₹36,108/Month',
#  '₹28,657/Month',
#  '₹71,643/Month',
#  '₹74,508/Month',
#  '₹46,997/Month']

# %%
Price=[]
for i in range(2,len(Emi),3):
    Price.append(Emi[i])

Price
# Out:
# ['₹1 Crore',
#  '₹65 Lacs',
#  '₹60 Lacs',
#  '₹1 Crore',
#  '₹88 Lacs',
#  '₹63 Lacs',
#  '₹50 Lacs',
#  '₹1.25 Crores',
#  '₹1.3 Crores',
#  '₹82 Lacs']

# %%
Details=pd.DataFrame({})
Details['Title']=H_title
Details['Location']=Loc
Details['Per Sq.ft']=Area
Details['Est_Emi']=Est_Emi
Details['Price']=Price

Details
# Out:
#                                                Title  \
# 0  2 BHK Flat  For Sale  In L&t Serene County  In...
# 1  2 BHK Flat  For Sale  In Gayathri Imperial, In...
# 2  2 BHK Flat  For Sale  In Veenus Excellance Apa...
# 3   2 BHK Flat  For Sale  In Golf Edge In Gachibowli
# 4  2 BHK Flat  For Sale  In Mokshagna Castle In M...
# 5  2 BHK Flat  For Sale  In Sai Residency, Gachib...
# 6  2 BHK Flat  For Sale  In G K Arcade In Nanakra...
# 7  2 BHK Apartment  For Sale  In My Home Vihanga ...
# 8  2 BHK Apartment  For Sale  In My Home Krishe I...
# 9  2 BHK Apartment  For Sale  In Shriya Sk Wonder...
#
#                                             Location   Per Sq.ft  \
# 0                                         Gachibowli  1,178 sqft
# 1  Gayathri Imperial, Plot 54 A Indira Nagar, Gac...  1,050 sqft
# 2           Near qcity, Gowlidoddy journalist colony  1,000 sqft
# 3  Financial District, Gachibowli, Hyderabad, Tel...  1,104 sqft
# ...

# %% [markdown]
# 7. Write a python program to scrape details of all the mobile phones under Rs. 20,000 listed on Amazon.in. The
# scraped data should include Product Name, Price, Image URL and Average Rating.

# %%
Page=requests.get("https://www.amazon.in/s?k=mobile+under+20000&ref=nb_sb_noss_1")
Page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(Page.content)

# %%
mobile_name=soup.find_all('span',class_="a-size-medium")
Mobile_name=[]
for i in mobile_name:
    Mobile_name.append(i.text)

Mobile_name
# Out:
# ['Redmi 9A (Nature Green, 2GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery',
#  'Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage) | 2.3GHz Mediatek Helio G35 Octa core Processor',
#  'realme C11 (2021) (Cool Blue, 2GB RAM, 32GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Samsung Galaxy M31 (Space Black, 6GB RAM, 128GB Storage)',
#  'realme C11 (2021) (Cool Grey, 2GB RAM, 32GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Redmi 9 Power (Mighty Black 4GB RAM 64GB Storage) - 6000mAh Battery |FHD+ Screen | 48MP Quad Camera | Alexa Hands-Free Capable',
#  'Redmi 9 Power (Mighty Black, 6GB RAM, 128GB Storage) - 6000mAh Battery |FHD+ Screen| 48MP Quad Camera | Snapdragon 662 Processor | Alexa Hands-Free Capable',
#  'Samsung Galaxy M31 (Ocean Blue, 6GB RAM, 128GB Storage)',
#  'Redmi Note 10 (Shadow Black, 4GB RAM, 64GB Storage) - Amoled Dot Display | 48MP Sony Sensor IMX582 | Snapdragon 678 Processor',
# ...

# %%
price=soup.find_all("span",class_="a-price-whole")
Price=[]
for i in price:
    Price.append(i.text)

Price
# Out:
# ['6,999',
#  '8,999',
#  '6,999',
#  '14,999',
#  '6,999',
#  '10,999',
#  '13,499',
#  '14,999',
#  '13,499',
#  '10,499',
#  '16,999',
#  '6,999',
#  '19,999',
#  '12,490',
#  '17,999',
#  '11,999']

# %%
images=soup.find_all("div", class_="a-section aok-relative s-image-fixed-height")
images_url=[]
for i in images[:10]:
    for j in i.find_all("img", class_="s-image"):
        images_url.append(j.get("src"))
images_url
# Out:
# ['https://m.media-amazon.com/images/I/71sxlhYhKWL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71A9Vo1BatL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71FYSKYFupS._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71OxJeyywSL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/618UBhFmaQS._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71hEzQGO5qL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/61LHaUOhehL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71-Su4Wr0HL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/81vixbGM2EL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71IkA3T7hIL._AC_UY218_.jpg']

# %%
avg_rating=soup.find_all("i", class_="a-icon a-icon-star-small a-star-small-4 aok-align-bottom")
ratings=[]
for i in avg_rating[:10]:
    ratings.append(i.text)

ratings
# Out:
# ['4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.1 out of 5 stars']

# %%
Details=pd.DataFrame({})
Details['Mobile_name']=Mobile_name[:10]
Details['Price']=Price[:10]
Details['URL']=images_url[:10]
Details['Rating']=ratings[:10]

Details
# Out:
#                                          Mobile_name   Price  \
# 0  Redmi 9A (Nature Green, 2GB RAM, 32GB Storage)...   6,999
# 1  Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage) | 2....   8,999
# 2  realme C11 (2021) (Cool Blue, 2GB RAM, 32GB St...   6,999
# 3  Samsung Galaxy M31 (Space Black, 6GB RAM, 128G...  14,999
# 4  realme C11 (2021) (Cool Grey, 2GB RAM, 32GB St...   6,999
# 5  Redmi 9 Power (Mighty Black 4GB RAM 64GB Stora...  10,999
# 6  Redmi 9 Power (Mighty Black, 6GB RAM, 128GB St...  13,499
# 7  Samsung Galaxy M31 (Ocean Blue, 6GB RAM, 128GB...  14,999
# 8  Redmi Note 10 (Shadow Black, 4GB RAM, 64GB Sto...  13,499
# 9  Samsung Galaxy M02s (Black,4GB RAM, 64GB Stora...  10,499
#
#                                                  URL              Rating
# 0  https://m.media-amazon.com/images/I/71sxlhYhKW...  4.2 out of 5 stars
# 1  https://m.media-amazon.com/images/I/71A9Vo1Bat...  4.2 out of 5 stars
# 2  https://m.media-amazon.com/images/I/71FYSKYFup...  4.1 out of 5 stars
# ...

# %%
for j in range(1, len(Pts),2):
    Points.append(Pts[j])

Points
# Out:
# ['2,955',
#  1,
#  3,
#  5,
#  7,
#  9,
#  11,
#  13,
#  15,
#  17,
#  '2,370',
#  '2,828',
#  '2,535',
#  '1,947',
#  '1,427',
#  '1,496',
#  '306',
#  '519',
#  '25',
#  '2,370',
#  '2,828',
#  '2,535',
#  '1,947',
#  '1,427',
#  '1,496',
#  '306',
#  '519',
#  '25']
